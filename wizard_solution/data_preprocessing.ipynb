# %%
import pandas as pd
#------------------------------------
pd.options.display.max_columns= None
pd.options.display.max_colwidth= None
pd.options.display.max_rows = None

#------------------------------------

# %%
# # Replace with the paths to your Excel files
# file0 = '/home/mahdi/Loan_Reommender_System/wizard_solution/data_preprocessing/data_Farabank/Fragment_1-10000.xlsx'
# file1 = '/home/mahdi/Loan_Reommender_System/wizard_solution/data_preprocessing/data_Farabank/Fragment_10001-20000.xlsx'
# file2 = '/home/mahdi/Loan_Reommender_System/wizard_solution/data_preprocessing/data_Farabank/Fragment_20001-30000.xlsx'
# file3 = '/home/mahdi/Loan_Reommender_System/wizard_solution/data_preprocessing/data_Farabank/Fragment_30001-40000.xlsx'
# file4 = '/home/mahdi/Loan_Reommender_System/wizard_solution/data_preprocessing/data_Farabank/Fragment_40001-50000.xlsx'

# # Read all files
# df0 = pd.read_excel(file0)
# df1 = pd.read_excel(file1)
# df2 = pd.read_excel(file2)
# df3 = pd.read_excel(file3)
# df4 = pd.read_excel(file4)
# # Concatenate dataframes
# merged_df = pd.concat([df0, df1, df2, df3, df4],ignore_index=True)

# # Save to a new Excel file
# merged_df.to_excel('merged_file.xlsx', index=False)

# %%
# df1.shape

# %%
df2.shape
# Out:
# (10000, 111)

# %%
merged_df.shape
# Out:
# (49999, 111)

# %%
df_reduced = pd.read_excel('/home/mahdi/Loan_Reommender_System/wizard_solution/data_preprocessing/merged_file_reduced.xlsx')
df_reduced.shape
# Out:
# (21106, 66)

# %%
df_reduced.head()
# Out:
#   عنوان مدیریت شعب عنوان شعبه  کد شعبه جنسیت  شماره تسهیلات  شماره حساب  \
# 0    مستقل فرابانک    فرابانک    67280    زن  1403455277206  1142494886
# 1    مستقل فرابانک    فرابانک    67280   مرد  1403536957649      108780
# 2    مستقل فرابانک    فرابانک    67280   مرد  1403492298963   433580571
# 3    مستقل فرابانک    فرابانک    67280    زن  1403467526729      179628
# 4    مستقل فرابانک    فرابانک    67280   مرد  1403482742163      226791
#
#     شماره مشتری                     کد ملی هش شده  تاریخ تولد / تاریخ ثبت  \
# 0      45878791  7b0c1340d1a9eff780958b3151c3c121                13450630
# 1  145018718389  368dbd48f1e44abe3dfe5222cdf50d81                13430726
# 2  131016842466  728ac6d6fbab6a3ad1106dc0095bffc3                13430110
# 3  140011749957  debc80e83b3c466ef9cb474111b613f6                13560628
# 4      61723827  ec409c90a4b6ce0b56d58712424a2ee3                13560625
#
#   محل ثبت / محل صدور  پیش شماره تلفن  رتبه مشتری  درآمدماهیانه  \
# ...

# %%
# selected_columns = [
#     "عنوان مدیریت شعب",
#     "عنوان شعبه",
#     "کد شعبه",
#     "جنسیت",
#     "شماره تسهیلات",
#     "شماره حساب",
#     "شماره مشتری",
#     "کد ملی هش شده",
#     "تاریخ تولد / تاریخ ثبت",
#     "محل ثبت / محل صدور",
#     "پیش شماره تلفن",
#     "رتبه مشتری",
#     "درآمدماهیانه",
#     "توان بازپرداخت",
#     "تعداد روزکاری تعیین وضعیت درخواست",
#     "مبلغ درخواستی تسهیلات",
#     "تاریخ درخواست",
#     "darkhast",
#     "کد بسته",
#     "شرح بسته",
#     "عنوان عقد",
#     "کد عقد",
#     "عنوان تسهیلات",
#     "کد تسهیلات",
#     "کد شرح متناظر",
#     "شرح متناظر",
#     "تاریخ تنظیم پیشنهاد",
#     "مدت تسهیلات",
#     "نرخ سود / کارمزد",
#     "نرخ جریمه",
#     "نرخ سود تعهد مشتری",
#     "مبلغ پیشنهاد",
#     "تاریخ ثبت قرارداد",
#     "مبلغ قرارداد",
#     "سود مهلت پرداخت قرارداد",
#     "مبلغ تعهد بانک",
#     "مبلغ خالص اعطا",
#     "مبلغ تسهیلات اعطایی",
#     "آخرین تاریخ اعطا",
#     "eta",
#     "تعداد اقساط",
#     "مبلغ اقساط",
#     "فاصله اقساط به ماه",
#     "تاریخ اولین سررسید اولین قسط",
#     "تاریخ سررسید نهایی",
#     "تعداد اقساط سررسید شده",
#     "تعداد اقساط پرداخت شده",
#     "تعداد اقساط باقیمانده",
#     "تعداد ضامن",
#     "تعداد قرارداد های لازم الاجرا",
#     "مبلغ قرارداد های لازم الاجرا",
#     "وضعیت تسهیلات",
#     "قدمت مطالبات",
#     "اولین تاریخ انتقال به وضعیت فعلی",
#     "وضعیت تسویه",
#     "تاریخ تسویه",
#     "تاریخ آخرین بازپرداخت",
#     "بازپرداخت شده از اصل",
#     "بازپرداخت شده از سود",
#     "بازپرداخت شده از جریمه",
#     "بازپرداخت شده از کارمزد",
#     "بازپرداخت شده از هزینه قانونی",
#     "مجموع مبلغ بازپرداختی",
#     "مانده بدهی سررسید شده - اصل",
#     "مانده بدهی سررسید شده - سود",
#     "مبلغ سود سالهای آینده"
# ]

# %%
selected_columns = [
    "عنوان مدیریت شعب",
    "جنسیت",
    "شماره حساب",
    "شماره مشتری",
    "محل ثبت / محل صدور",
    "پیش شماره تلفن",
    "رتبه مشتری",
    "درآمدماهیانه",
    "توان بازپرداخت",
    "مبلغ درخواستی تسهیلات",
    "تاریخ درخواست",
    "darkhast",
    "کد بسته",
    "شرح بسته",
    "عنوان عقد",
    "کد عقد",
    "عنوان تسهیلات",
    "کد تسهیلات",
    "مدت تسهیلات",
    "نرخ سود / کارمزد",
    "آخرین تاریخ اعطا",
    "eta",
    "تعداد اقساط",
    "مبلغ اقساط",
    "فاصله اقساط به ماه",
    "تاریخ اولین سررسید اولین قسط",
    "تاریخ سررسید نهایی",
    "تعداد اقساط سررسید شده",
    "تعداد ضامن",
    "تعداد قرارداد های لازم الاجرا",
    "مبلغ قرارداد های لازم الاجرا",
    "وضعیت تسهیلات",
    "تاریخ آخرین بازپرداخت",
    "مجموع مبلغ بازپرداختی",
    "مانده بدهی سررسید شده - اصل",
    "مانده بدهی سررسید شده - سود",
    "مبلغ سود سالهای آینده"
]


df_selected = df_reduced[selected_columns]
# Save to a new Excel file
df_selected.to_excel('selected_mergloan.xlsx', index=False)

# %%
selected_columns = [
    # "عنوان مدیریت شعب",
    # "جنسیت",
    # "شماره حساب",
    "شماره مشتری",
    # "محل ثبت / محل صدور",
    # "پیش شماره تلفن",
    "رتبه مشتری",
    "درآمدماهیانه",
    "توان بازپرداخت",
    "مبلغ درخواستی تسهیلات",
    # "تاریخ درخواست",
    "darkhast",
    # "کد بسته",
    "شرح بسته",
    "عنوان عقد",
    # "کد عقد",
    "عنوان تسهیلات",
    # "کد تسهیلات",
    "مدت تسهیلات",
    "نرخ سود / کارمزد",
    # "آخرین تاریخ اعطا",
    "eta",
    "تعداد اقساط",
    "مبلغ اقساط",
    # "فاصله اقساط به ماه",
    # "تاریخ اولین سررسید اولین قسط",
    # "تاریخ سررسید نهایی",
    # "تعداد اقساط سررسید شده",
    "تعداد ضامن",
    "تعداد قرارداد های لازم الاجرا",
    "مبلغ قرارداد های لازم الاجرا",
    # "وضعیت تسهیلات",
    # "تاریخ آخرین بازپرداخت",
    # "مجموع مبلغ بازپرداختی",
    # "مانده بدهی سررسید شده - اصل",
    # "مانده بدهی سررسید شده - سود",
    # "مبلغ سود سالهای آینده"
]


df_selected = df_reduced[selected_columns]

# %%
df_selected.shape
# Out:
# (21106, 17)
